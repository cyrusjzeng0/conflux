# %% [markdown]
# ## initializing payload structure

# %%
from faker import Faker
import random

fake = Faker()

EVENTS = ["play_song", "create_new_playlist", "add_song_to_playlist", "remove_song_from_playlist", "delete_playlist"]
SUBSCRIPTION_TYPES = ["free", "premium"]

USER_IDS = [fake.uuid4() for _ in range(1000)]
SONG_IDS = [fake.uuid4() for _ in range(10000)]
PLAYLIST_IDS = [fake.uuid4() for _ in range(1000)]

def build_properties(event_type: str) -> dict:
    if event_type == "play_song":
        return {
            "song_id": random.choice(SONG_IDS)
        }
    elif event_type == "create_new_playlist":
        return {
            "playlist_name": fake.word()
        }
    elif event_type in ["add_song_to_playlist", "remove_song_from_playlist"]:
        return {
            "playlist_id": random.choice(PLAYLIST_IDS),
            "song_id": random.choice(SONG_IDS)
        }
    elif event_type == "delete_playlist":
        return {
            "playlist_id": random.choice(PLAYLIST_IDS)
        }

event_type = random.choice(EVENTS)

payload = {
    "event_id": fake.uuid4(),
    "event_type": event_type, 
    "event_timestamp": fake.date_time_this_year().isoformat(),
    "user_id": random.choice(USER_IDS),
    "user_country": fake.country(),
    "user_subscription_type": random.choice(SUBSCRIPTION_TYPES),
    "event_properties": build_properties(event_type)
}

# %% [markdown]
# ## generating fake events

# %%
import time
import json

n = 3

def generate_batch_events(events_per_n_secs: int):
    events = []
    for _ in range(events_per_n_secs):
        event_type = random.choice(EVENTS)
        payload = {
            "event_id": fake.uuid4(),
            "event_type": event_type, 
            "event_timestamp": fake.date_time_this_year().isoformat(),
            "user_id": random.choice(USER_IDS),
            "user_country": fake.country(),
            "user_subscription_type": random.choice(SUBSCRIPTION_TYPES),
            "event_properties": build_properties(event_type)
        }
        events.append(payload)
    
    return events

for i in range(10):
    num_events = random.randint(0, 5)
    print(num_events)
    print(json.dumps(generate_batch_events(num_events)))
    time.sleep(n)
# Out:
# 4
# [{"event_id": "2d157831-4e36-45dd-8c9f-772841f7a08b", "event_type": "add_song_to_playlist", "event_timestamp": "2026-02-11T03:01:04.037003", "user_id": "b39b93ab-82ec-4308-8f94-ecfdf1904ef9", "user_country": "Germany", "user_subscription_type": "premium", "event_properties": {"playlist_id": "c3e89034-464d-4b36-bceb-775a65b55e81", "song_id": "867667db-5543-483b-9031-3de75bdb2943"}}, {"event_id": "e885f708-4aa0-42cc-b1dc-39c56e762b70", "event_type": "play_song", "event_timestamp": "2026-07-02T12:53:28.118685", "user_id": "58cb6153-7fb3-4c6c-9d8b-38d171f9d4cf", "user_country": "United States Virgin Islands", "user_subscription_type": "premium", "event_properties": {"song_id": "676df0dc-f693-42a2-95ce-39fb4f1cf08b",
_subscription_type": "free", "event_properties": {"song_id": "c6fd063f-95a0-4313-96c3-a8ebd46d3c8b", "song_name": "system", "song_artist": "Peter Moore", "song_album": "important"}}, {"event_id": "49d6ee76-a74d-4336-acf2-bc490c4f1559", "event_type": "play_song", "event_timestamp": "2026-02-11T15:30:09.237608", "user_id": "35e33676-a02e-474b-9b01-8759af953c28", "user_country": "Netherlands Antilles", "user_subscription_type": "free", "event_properties": {"song_id": "9cc9bd1a-553c-4c52-804a-981d6e677ead", "song_name": "American", "song_artist": "Karen Rodriguez", "song_album": "theory"}}]
# 2
# [{"event_id": "7fcf7c0c-a56d-472a-95d9-00a67102a94d", "event_type": "create_new_playlist", "event_timestamp": "2026-06-27T06:11:54.694312", "user_id": "ec3c1f82-f542-4355-bfa7-f92a0b5d620c", "user_country": "Botswana", "user_subscription_type": "premium", "event_properties": {"playlist_name": "financial"}}, {"event_id": "edb71c98-d94c-4c19-bb02-02d788b13a8d", "event_type": "create_new_playlist", "event_timestamp": "2026-03-19T20:12:43.651834", "user_id": "10f16526-358d-4936-951f-cb56aa2b4ac0", "user_country": "Bermuda", "user_subscription_type": "free", "event_properties": {"playlist_name": "shake"}}]
# 3
# [{"event_id": "554bc46c-9a24-473e-bf96-79ee932518cb", "event_type": "add_song_to_playlist", "event_timestamp": "2026-07-23T10:13:13.243235", "user_id": "16c8e5b1-0708-49e0-a0a9-c0f72fef04eb", "user_country": "Poland", "user_subscription_type": "premium", "event_properties": {"playlist_id": "819a6417-89ef-4df6-ad75-c1b7a08b332d", "song_id": "1786b006-0e4b-413c-b98c-1f8472e5bb42"}}, {"event_id": "888ebd99-7281-443d-943f-9ccd031189d9", "event_type": "add_song_to_playlist", "event_timestamp": "2026-06-04T05:25:31.348077", "user_id": "c2cd5a1a-4853-4ad6-a1ab-6f6337dc4cc6", "user_country": "Micronesia", "user_subscription_type": "premium", "event_properties": {"playlist_id": "256083fa-b535-4052-b85d-18b51dd36716", "song_id": "b281045c-73b2-45ce-aca2-69b183d9b41f"}}, {"event_id": "83cb5c1f-b7d0-41fc-8a26-ee53d28a6036", "event_type": "delete_playlist", "event_timestamp": "2026-02-13T06:14:19.416863", "user_id": "39f66005-ecd9-4b58-ad38-e61895d34e4e", "user_country": "Puerto Rico", "user_subscription_type": "premium", "event_properties": {"playlist_id": "cbe96e25-5805-4ae5-8210-b881dfcd3778"}}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 27
#      23 for i in range(10):
#      24     num_events = random.randint(0, 5)
#      25     print(num_events)
#      26     print(json.dumps(generate_batch_events(num_events)))
# ---> 27     time.sleep(n)
#
# KeyboardInterrupt:
